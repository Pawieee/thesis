# %% [markdown]
# # =============================================================================
# # CBAM + DENSENET121 — TRAIN-VAL-TEST SPLIT EVALUATION
# # =============================================================================
# Evaluates the DenseNet121 + CBAM model (frozen backbone → binary classification) on
# **per-dataset** splits at configurable **train-val-test** ratios (60:20:20, 65:18:18, 70:15:15).
#
# Dataset:**BHSig-Hindi**
#
# **Prerequisites:**
# 1. Run `scripts/prepare_split_ratios.py` to generate split JSONs.

# %% [markdown]
# # =============================================================================
# # STEP 1: SETUP, IMPORTS, AND REPRODUCIBILITY
# # =============================================================================

# %%
import os
import sys
import json
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from PIL import Image

# Set repo root
current_dir = os.path.abspath(os.getcwd())
REPO_ROOT = os.path.abspath(os.path.join(current_dir, '..'))
if REPO_ROOT not in sys.path:
    sys.path.append(REPO_ROOT)

# Import Custom Modules
from models.feature_extractor import DenseNetFeatureExtractor
from utils.model_evaluation import compute_metrics, _plot_det_curve, _plot_far_frr, _plot_confusion_matrix, _plot_score_distribution, _plot_roc_curve
from dataloader.tDCBAM_trainloader import get_baseline_transforms

# Deterministic Seeding
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f" > [System] Seed set to: {seed}")

seed_everything(42)

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f" > [System] Device: {DEVICE}")
print(f" > [System] CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f" > [System] CUDA Device Name: {torch.cuda.get_device_name()}")
# Out:
# /home/lawrence/workspace/thesis/thesis/.venv/lib/python3.12/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
#  > [System] Seed set to: 42
#  > [System] Device: cuda
#  > [System] CUDA Available: True
#  > [System] CUDA Device Name: NVIDIA GeForce RTX 5080

# %% [markdown]
# # =============================================================================
# # STEP 2: CONFIGURATION
# # =============================================================================

# %%
# ────────────────────────────────────────────────────────────────────
# STEP 2: Configuration and Hyperparameters
# ────────────────────────────────────────────────────────────────────

# Notebook identifier
NOTEBOOK_NAME = 'CBAM_hindi'
DATASET = 'bhsig_hindi'
DATASET_NAME = 'BHSig-Hindi'

# Paths
SPLIT_DIR = '../data/ratio_splits'
CHECKPOINT_DIR = '../checkpoints/CBAM_splits'
EVAL_DIR = f'../model_evals/{NOTEBOOK_NAME}'

# Data splits - now using train:val:test ratios
SPLIT_RATIOS = ['65_18_18', '70_15_15', '60_20_20']

# Training Configuration
EPOCHS = 100
BATCH_SIZE = 30
LR = 1e-3
MOMENTUM = 0.99

# Data Configuration  
INPUT_SHAPE = (224, 224)
IMG_SIZE = 224
PREPROCESS = True
AUGMENT = True

os.makedirs(CHECKPOINT_DIR, exist_ok=True)
os.makedirs(EVAL_DIR, exist_ok=True)

print(" > Configuration loaded:")
print(f"   Dataset       : {DATASET_NAME}")
print(f"   Split Ratios  : {SPLIT_RATIOS}")
print(f"   Epochs        : {EPOCHS}")
print(f"   Batch Size    : {BATCH_SIZE}")
print(f"   Learning Rate : {LR}")
print(f"   Image Size    : {IMG_SIZE}x{IMG_SIZE}")
print(f"   Checkpoint Dir: {CHECKPOINT_DIR}")
print(f"   Eval Dir      : {EVAL_DIR}")
# Out:
#  > Configuration loaded:
#    Dataset       : BHSig-Hindi
#    Split Ratios  : ['65_18_18', '70_15_15', '60_20_20']
#    Epochs        : 100
#    Batch Size    : 30
#    Learning Rate : 0.001
#    Image Size    : 224x224
#    Checkpoint Dir: ../checkpoints/CBAM_splits
#    Eval Dir      : ../model_evals/CBAM_hindi

# %% [markdown]
# # =============================================================================
# # STEP 3: GENERATE SPLITS (if not already generated)
# # =============================================================================

# %% [markdown]
# # =============================================================================
# # STEP 4: DATASET CLASS AND TRANSFORMS
# # =============================================================================

# %%
class SplitDataset(Dataset):
    """
    Binary classification dataset (Genuine=0, Forged=1) from split JSON.
    Works with CEDAR, BHSig-Bengali, and BHSig-Hindi split files.
    """
    def __init__(self, user_dict, transform=None):
        self.samples = []
        self.transform = transform
        
        for uid, data in user_dict.items():
            # Handle both key styles: 'genuine'/'forged' and 'gen'/'forg'
            gen_key = next((k for k in data.keys() if k.lower() in ['genuine', 'gen']), None)
            forg_key = next((k for k in data.keys() if k.lower() in ['forged', 'forgeries', 'forg']), None)
            
            if gen_key:
                for path in data[gen_key]:
                    self.samples.append((path, 0))  # 0 = Genuine
            if forg_key:
                for path in data[forg_key]:
                    self.samples.append((path, 1))  # 1 = Forged
        
        num_gen = sum(1 for _, l in self.samples if l == 0)
        num_forg = sum(1 for _, l in self.samples if l == 1)
        print(f"   Dataset: {len(self.samples)} samples ({num_gen} genuine + {num_forg} forged) from {len(user_dict)} users")
    
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        try:
            img = Image.open(img_path).convert('RGB')
            if self.transform:
                img = self.transform(img)
        except Exception as e:
            img = torch.zeros(3, IMG_SIZE, IMG_SIZE)
        return img, label

# Transforms
train_transform, val_transform = get_baseline_transforms(
    input_shape=INPUT_SHAPE, preprocess=PREPROCESS, augment=AUGMENT
)

print(" > Dataset class and transforms defined")
# Out:
#  > Dataset class and transforms defined

# %% [markdown]
# # =============================================================================
# # STEP 5: TRAINING UTILITIES
# # =============================================================================

# %%
def initialize_cbam_model(device):
    """Initialize DenseNet121 + CBAM with ImageNet pretrained weights."""
    num_classes = 2
    model = DenseNetFeatureExtractor(
        backbone_name='densenet121', output_dim=num_classes,
        pretrained=True, baseline=False  # CBAM enabled
    ).to(device)
    print(f"   Using ImageNet initialization with CBAM")
    return model


def train_one_epoch(model, loader, optimizer, criterion, device):
    """Train for one epoch, returns avg loss and accuracy."""
    model.train()
    total_loss, correct, total = 0.0, 0, 0
    
    for images, labels in tqdm(loader, desc="Training", leave=False):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
    
    return total_loss / len(loader), correct / total


def evaluate_model(model, loader, device, output_dir=None, silent=False):
    """Evaluate model and compute metrics including EER."""
    model.eval()
    all_labels, all_scores = [], []
    
    iter_bar = tqdm(loader, desc="Evaluating", leave=False) if not silent else loader
    
    with torch.no_grad():
        for images, labels in iter_bar:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            probs = torch.softmax(outputs, dim=1)[:, 1]
            all_scores.extend(probs.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    metrics = compute_metrics(all_labels, all_scores)
    
    if output_dir and not silent:
        # Full Reporting
        print(f"\n{'='*10} FINAL TEST RESULTS {'='*10}")
        print(f"EER            : {metrics['eer']:.2%}")
        print(f"AUC            : {metrics['auc']:.4f}")
        print(f"Best Threshold : {metrics.get('threshold', 0):.4f}")
        print(f"Accuracy       : {metrics['accuracy']:.2%}")
        print(f"Precision      : {metrics.get('precision', 0):.2%}")
        print(f"Recall         : {metrics.get('recall', 0):.2%}")
        print(f"F1-Score       : {metrics.get('f1', 0):.2%}")
        print("="*40)
        
        _plot_roc_curve(metrics, output_dir)
        _plot_score_distribution(metrics, output_dir)
        _plot_confusion_matrix(metrics, output_dir)
        _plot_det_curve(metrics, output_dir)
        _plot_far_frr(metrics, output_dir)
    
    return metrics


def train_full_pipeline(model, train_loader, val_loader, device, 
                        epochs, lr, checkpoint_path):
    """
    Train-Val-Test strategy: Use train for optimization, val for model selection.
    Returns best validation metrics dict.
    """
    criterion = nn.CrossEntropyLoss()
    best_eer, best_acc, best_metrics = 1.0, 0.0, {}
    
    # All parameters trainable
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4, betas=(MOMENTUM, MOMENTUM))
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)
    
    for epoch in range(epochs):
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion, device)
        val_metrics = evaluate_model(model, val_loader, device, silent=True)
        val_eer, val_acc = val_metrics['eer'], val_metrics['accuracy']
        
        print(f"   Epoch {epoch+1:02d}/{epochs} | Loss: {train_loss:.4f} | "
              f"Acc: {train_acc:.2%} | Val EER: {val_eer:.2%} | Val Acc: {val_acc:.2%}")
        scheduler.step(val_eer)
        
        if val_eer < best_eer or (val_eer == best_eer and val_acc > best_acc):
            best_eer, best_acc, best_metrics = val_eer, val_acc, val_metrics
            torch.save({'model_state_dict': model.state_dict(), 'metrics': best_metrics}, checkpoint_path)
            print(f"   >>> Saved! (EER: {val_eer:.2%})")
    
    return best_metrics


print(" > Training utilities defined")
# Out:
#  > Training utilities defined

# %% [markdown]
# # =============================================================================
# # STEP 6: RUN ALL SPLIT RATIOS
# # =============================================================================

# %%
all_results = {}

for ratio in SPLIT_RATIOS:
    split_file = os.path.join(SPLIT_DIR, f"{DATASET}_split_{ratio}.json")
    train_pct, val_pct, test_pct = ratio.split('_')
    split_eval_dir = os.path.join(EVAL_DIR, f"{NOTEBOOK_NAME}_{train_pct}-{val_pct}-{test_pct}")
    os.makedirs(split_eval_dir, exist_ok=True)
    
    print(f"\n{'='*60}")
    print(f" {DATASET_NAME} -- {train_pct}:{val_pct}:{test_pct} Split")
    print(f"{'='*60}")
    
    if not os.path.exists(split_file):
        print(f"   SKIPPED: Split file not found: {split_file}")
        continue
    
    # Load split - now with train/val/test
    with open(split_file, 'r') as f:
        split_data = json.load(f)
    
    train_dict = split_data['train']
    val_dict = split_data['val']
    test_dict = split_data['test']
    
    print(f"   Train users: {len(train_dict)} | Val users: {len(val_dict)} | Test users: {len(test_dict)}")
    
    # Create datasets
    print("   Creating train dataset...")
    train_dataset = SplitDataset(train_dict, transform=train_transform)
    print("   Creating val dataset...")
    val_dataset = SplitDataset(val_dict, transform=val_transform)
    print("   Creating test dataset...")
    test_dataset = SplitDataset(test_dict, transform=val_transform)
    
    if len(train_dataset) == 0 or len(val_dataset) == 0 or len(test_dataset) == 0:
        print(f"   SKIPPED: Empty dataset")
        continue
    
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, 
                              num_workers=4, pin_memory=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False,
                            num_workers=4, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False,
                             num_workers=4, pin_memory=True)
    
    # Initialize model
    seed_everything(42)
    model = initialize_cbam_model(DEVICE)
    
    # Train using train set, validate on val set for model selection
    ckpt_path = os.path.join(CHECKPOINT_DIR, f"best_{DATASET}_{ratio}.pth")
    best_val_metrics = train_full_pipeline(
        model, train_loader, val_loader, DEVICE,
        epochs=EPOCHS, lr=LR,
        checkpoint_path=ckpt_path
    )
    
    # Load best checkpoint and evaluate on test set (NEVER seen during training)
    if os.path.exists(ckpt_path):
        checkpoint = torch.load(ckpt_path, map_location=DEVICE, weights_only=False)
        state = checkpoint.get('model_state_dict', checkpoint)
        model.load_state_dict(state)
    
    final_test_metrics = evaluate_model(model, test_loader, DEVICE, output_dir=split_eval_dir, silent=False)
    
    # Record results
    result_key = f"{DATASET_NAME} ({train_pct}:{val_pct}:{test_pct})"
    all_results[result_key] = {
        'dataset': DATASET_NAME,
        'split': f"{train_pct}:{val_pct}:{test_pct}",
        'train_users': len(train_dict),
        'val_users': len(val_dict),
        'test_users': len(test_dict),
        'eer': float(final_test_metrics['eer']),
        'accuracy': float(final_test_metrics['accuracy']),
        'auc': float(final_test_metrics['auc']),
        'precision': float(final_test_metrics['precision']),
        'recall': float(final_test_metrics['recall']),
        'f1': float(final_test_metrics['f1']),
    }
    
    print(f"\n   TEST SET RESULT: EER={final_test_metrics['eer']:.2%} | Acc={final_test_metrics['accuracy']:.2%} | "
          f"AUC={final_test_metrics['auc']:.4f} | F1={final_test_metrics['f1']:.4f}")

print(f"\n{'='*60}")
print("ALL EXPERIMENTS COMPLETE")
print(f"{'='*60}")
# Out:
# ============================================================
#  BHSig-Hindi -- 65:18:18 Split
# ============================================================
#    Train users: 104 | Val users: 28 | Test users: 28
#    Creating train dataset...
#    Dataset: 5616 samples (2496 genuine + 3120 forged) from 104 users
#    Creating val dataset...
#    Dataset: 1512 samples (672 genuine + 840 forged) from 28 users
#    Creating test dataset...
#    Dataset: 1512 samples (672 genuine + 840 forged) from 28 users
#  > [System] Seed set to: 42
#    Using ImageNet initialization with CBAM
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 01/100 | Loss: 0.6387 | Acc: 68.77% | Val EER: 28.57% | Val Acc: 71.49%
#    >>> Saved! (EER: 28.57%)
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 02/100 | Loss: 0.5621 | Acc: 74.05% | Val EER: 24.70% | Val Acc: 75.13%
#    >>> Saved! (EER: 24.70%)
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 03/100 | Loss: 0.5184 | Acc: 77.38% | Val EER: 20.09% | Val Acc: 79.96%
#    >>> Saved! (EER: 20.09%)
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 04/100 | Loss: 0.4666 | Acc: 78.91% | Val EER: 20.68% | Val Acc: 79.37%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 05/100 | Loss: 0.4290 | Acc: 80.93% | Val EER: 20.68% | Val Acc: 79.23%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 06/100 | Loss: 0.4492 | Acc: 80.68% | Val EER: 19.20% | Val Acc: 80.82%
#    >>> Saved! (EER: 19.20%)
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 07/100 | Loss: 0.4522 | Acc: 79.95% | Val EER: 15.77% | Val Acc: 84.13%
#    >>> Saved! (EER: 15.77%)
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 08/100 | Loss: 0.4083 | Acc: 82.55% | Val EER: 16.22% | Val Acc: 83.73%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 09/100 | Loss: 0.3742 | Acc: 84.63% | Val EER: 22.02% | Val Acc: 77.98%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 10/100 | Loss: 0.3958 | Acc: 83.12% | Val EER: 19.20% | Val Acc: 80.95%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 11/100 | Loss: 0.4122 | Acc: 82.62% | Val EER: 21.88% | Val Acc: 78.11%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 12/100 | Loss: 0.4389 | Acc: 80.64% | Val EER: 19.79% | Val Acc: 80.42%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 13/100 | Loss: 0.3800 | Acc: 83.96% | Val EER: 16.07% | Val Acc: 83.93%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 14/100 | Loss: 0.3474 | Acc: 85.58% | Val EER: 16.37% | Val Acc: 83.60%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 15/100 | Loss: 0.3420 | Acc: 85.44% | Val EER: 16.52% | Val Acc: 83.47%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 16/100 | Loss: 0.3186 | Acc: 86.56% | Val EER: 18.30% | Val Acc: 81.81%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 17/100 | Loss: 0.3124 | Acc: 86.90% | Val EER: 19.49% | Val Acc: 80.56%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 18/100 | Loss: 0.3009 | Acc: 88.04% | Val EER: 17.86% | Val Acc: 82.08%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 19/100 | Loss: 0.2831 | Acc: 88.43% | Val EER: 17.56% | Val Acc: 82.41%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 20/100 | Loss: 0.2652 | Acc: 89.16% | Val EER: 18.30% | Val Acc: 81.68%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 21/100 | Loss: 0.2561 | Acc: 89.25% | Val EER: 18.60% | Val Acc: 81.42%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 22/100 | Loss: 0.2506 | Acc: 90.11% | Val EER: 20.24% | Val Acc: 79.89%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 23/100 | Loss: 0.2366 | Acc: 90.36% | Val EER: 20.09% | Val Acc: 79.83%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 24/100 | Loss: 0.2358 | Acc: 90.77% | Val EER: 19.20% | Val Acc: 81.15%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 25/100 | Loss: 0.2280 | Acc: 90.36% | Val EER: 18.30% | Val Acc: 81.68%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 26/100 | Loss: 0.2137 | Acc: 91.32% | Val EER: 20.09% | Val Acc: 80.03%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 27/100 | Loss: 0.2154 | Acc: 91.05% | Val EER: 19.20% | Val Acc: 80.22%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 28/100 | Loss: 0.2051 | Acc: 92.09% | Val EER: 18.75% | Val Acc: 81.68%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 29/100 | Loss: 0.2103 | Acc: 91.60% | Val EER: 20.24% | Val Acc: 79.63%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 30/100 | Loss: 0.2107 | Acc: 91.71% | Val EER: 19.94% | Val Acc: 80.03%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 31/100 | Loss: 0.1960 | Acc: 92.34% | Val EER: 20.24% | Val Acc: 79.76%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 32/100 | Loss: 0.2012 | Acc: 91.78% | Val EER: 18.30% | Val Acc: 81.94%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 33/100 | Loss: 0.1819 | Acc: 92.39% | Val EER: 18.75% | Val Acc: 81.28%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 34/100 | Loss: 0.1891 | Acc: 92.51% | Val EER: 19.05% | Val Acc: 80.82%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 35/100 | Loss: 0.1887 | Acc: 92.07% | Val EER: 18.45% | Val Acc: 81.75%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 36/100 | Loss: 0.1889 | Acc: 92.39% | Val EER: 19.05% | Val Acc: 81.02%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 37/100 | Loss: 0.1838 | Acc: 92.67% | Val EER: 18.90% | Val Acc: 81.02%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 38/100 | Loss: 0.1765 | Acc: 93.26% | Val EER: 18.90% | Val Acc: 80.89%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 39/100 | Loss: 0.1801 | Acc: 92.82% | Val EER: 18.30% | Val Acc: 81.55%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 40/100 | Loss: 0.1895 | Acc: 92.58% | Val EER: 18.15% | Val Acc: 81.88%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 41/100 | Loss: 0.1674 | Acc: 93.42% | Val EER: 18.45% | Val Acc: 81.55%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 42/100 | Loss: 0.1759 | Acc: 92.76% | Val EER: 17.41% | Val Acc: 82.47%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 43/100 | Loss: 0.1694 | Acc: 93.24% | Val EER: 18.01% | Val Acc: 82.34%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 44/100 | Loss: 0.1821 | Acc: 92.58% | Val EER: 18.60% | Val Acc: 81.28%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 45/100 | Loss: 0.1672 | Acc: 93.42% | Val EER: 18.30% | Val Acc: 81.75%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 46/100 | Loss: 0.1747 | Acc: 93.19% | Val EER: 18.01% | Val Acc: 81.94%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 47/100 | Loss: 0.1739 | Acc: 93.19% | Val EER: 18.15% | Val Acc: 81.88%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 48/100 | Loss: 0.1727 | Acc: 92.94% | Val EER: 19.64% | Val Acc: 80.29%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 49/100 | Loss: 0.1832 | Acc: 92.44% | Val EER: 19.35% | Val Acc: 80.69%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 50/100 | Loss: 0.1669 | Acc: 93.32% | Val EER: 18.60% | Val Acc: 81.35%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 51/100 | Loss: 0.1727 | Acc: 93.14% | Val EER: 18.30% | Val Acc: 81.68%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 52/100 | Loss: 0.1750 | Acc: 92.85% | Val EER: 18.45% | Val Acc: 81.55%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 53/100 | Loss: 0.1730 | Acc: 92.60% | Val EER: 18.75% | Val Acc: 81.22%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 54/100 | Loss: 0.1653 | Acc: 93.26% | Val EER: 19.20% | Val Acc: 80.89%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 55/100 | Loss: 0.1704 | Acc: 93.26% | Val EER: 19.05% | Val Acc: 81.02%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 56/100 | Loss: 0.1717 | Acc: 93.69% | Val EER: 18.60% | Val Acc: 81.35%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 57/100 | Loss: 0.1772 | Acc: 92.60% | Val EER: 18.60% | Val Acc: 81.15%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 58/100 | Loss: 0.1820 | Acc: 92.87% | Val EER: 18.30% | Val Acc: 81.68%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 59/100 | Loss: 0.1619 | Acc: 93.78% | Val EER: 18.60% | Val Acc: 81.42%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 60/100 | Loss: 0.1646 | Acc: 93.53% | Val EER: 18.45% | Val Acc: 81.68%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 61/100 | Loss: 0.1715 | Acc: 93.16% | Val EER: 18.45% | Val Acc: 81.55%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 62/100 | Loss: 0.1666 | Acc: 93.17% | Val EER: 18.90% | Val Acc: 81.15%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 63/100 | Loss: 0.1701 | Acc: 93.01% | Val EER: 18.45% | Val Acc: 81.55%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 64/100 | Loss: 0.1789 | Acc: 92.37% | Val EER: 18.01% | Val Acc: 82.08%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 65/100 | Loss: 0.1654 | Acc: 93.57% | Val EER: 18.45% | Val Acc: 81.61%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 66/100 | Loss: 0.1674 | Acc: 93.16% | Val EER: 18.15% | Val Acc: 81.81%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 67/100 | Loss: 0.1728 | Acc: 93.01% | Val EER: 17.86% | Val Acc: 82.14%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 68/100 | Loss: 0.1729 | Acc: 93.10% | Val EER: 18.45% | Val Acc: 81.55%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 69/100 | Loss: 0.1723 | Acc: 93.32% | Val EER: 18.45% | Val Acc: 81.61%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 70/100 | Loss: 0.1636 | Acc: 93.78% | Val EER: 18.45% | Val Acc: 81.55%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 71/100 | Loss: 0.1719 | Acc: 92.98% | Val EER: 18.45% | Val Acc: 81.42%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 72/100 | Loss: 0.1820 | Acc: 92.60% | Val EER: 18.60% | Val Acc: 81.42%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 73/100 | Loss: 0.1624 | Acc: 93.74% | Val EER: 18.45% | Val Acc: 81.61%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 74/100 | Loss: 0.1668 | Acc: 93.49% | Val EER: 18.01% | Val Acc: 82.01%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 75/100 | Loss: 0.1716 | Acc: 93.28% | Val EER: 18.30% | Val Acc: 81.61%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 76/100 | Loss: 0.1665 | Acc: 93.42% | Val EER: 18.30% | Val Acc: 81.68%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 77/100 | Loss: 0.1752 | Acc: 93.03% | Val EER: 18.60% | Val Acc: 81.35%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 78/100 | Loss: 0.1711 | Acc: 93.28% | Val EER: 18.75% | Val Acc: 81.28%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 79/100 | Loss: 0.1651 | Acc: 93.96% | Val EER: 18.60% | Val Acc: 81.22%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 80/100 | Loss: 0.1682 | Acc: 93.30% | Val EER: 18.60% | Val Acc: 81.42%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 81/100 | Loss: 0.1655 | Acc: 93.24% | Val EER: 18.45% | Val Acc: 81.48%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 82/100 | Loss: 0.1625 | Acc: 93.51% | Val EER: 18.60% | Val Acc: 81.42%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 83/100 | Loss: 0.1671 | Acc: 93.19% | Val EER: 18.45% | Val Acc: 81.48%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 84/100 | Loss: 0.1839 | Acc: 92.60% | Val EER: 18.60% | Val Acc: 81.48%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 85/100 | Loss: 0.1690 | Acc: 93.42% | Val EER: 18.15% | Val Acc: 81.75%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 86/100 | Loss: 0.1704 | Acc: 93.55% | Val EER: 18.45% | Val Acc: 81.55%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 87/100 | Loss: 0.1603 | Acc: 94.01% | Val EER: 18.60% | Val Acc: 81.42%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 88/100 | Loss: 0.1726 | Acc: 92.92% | Val EER: 18.45% | Val Acc: 81.55%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 89/100 | Loss: 0.1660 | Acc: 93.07% | Val EER: 18.60% | Val Acc: 81.42%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 90/100 | Loss: 0.1649 | Acc: 93.49% | Val EER: 18.15% | Val Acc: 81.81%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 91/100 | Loss: 0.1783 | Acc: 92.96% | Val EER: 18.30% | Val Acc: 81.68%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 92/100 | Loss: 0.1624 | Acc: 93.33% | Val EER: 18.30% | Val Acc: 81.75%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 93/100 | Loss: 0.1706 | Acc: 93.03% | Val EER: 18.45% | Val Acc: 81.48%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 94/100 | Loss: 0.1715 | Acc: 93.44% | Val EER: 18.45% | Val Acc: 81.75%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 95/100 | Loss: 0.1753 | Acc: 93.32% | Val EER: 18.30% | Val Acc: 81.75%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 96/100 | Loss: 0.1716 | Acc: 92.94% | Val EER: 18.30% | Val Acc: 81.68%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 97/100 | Loss: 0.1667 | Acc: 93.58% | Val EER: 18.45% | Val Acc: 81.55%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 98/100 | Loss: 0.1750 | Acc: 93.05% | Val EER: 18.75% | Val Acc: 81.28%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 99/100 | Loss: 0.1768 | Acc: 93.21% | Val EER: 18.45% | Val Acc: 81.55%
# Training:   0%|          | 0/187 [00:00<?, ?it/s]
#    Epoch 100/100 | Loss: 0.1696 | Acc: 92.83% | Val EER: 18.45% | Val Acc: 81.68%
# Evaluating:   0%|          | 0/51 [00:00<?, ?it/s]
# ========== FINAL TEST RESULTS ==========
# EER            : 17.11%
# AUC            : 0.9161
# Best Threshold : 0.4029
# Accuracy       : 82.87%
# Precision      : 85.82%
# Recall         : 82.86%
# F1-Score       : 84.31%
# ========================================
#  > Saved ROC Plot to: ../model_evals/CBAM_hindi/CBAM_hindi_65-18-18/roc_curve.png
#  > Saved Distribution Plot to: ../model_evals/CBAM_hindi/CBAM_hindi_65-18-18/score_distribution.png
#  > Saved Confusion Matrix to: ../model_evals/CBAM_hindi/CBAM_hindi_65-18-18/confusion_matrix.png
#  > Saved DET Curve to: ../model_evals/CBAM_hindi/CBAM_hindi_65-18-18/det_curve.png
#  > Saved FAR/FRR Plot to: ../model_evals/CBAM_hindi/CBAM_hindi_65-18-18/far_frr.png
#
#    TEST SET RESULT: EER=17.11% | Acc=82.87% | AUC=0.9161 | F1=0.8431
#
# ============================================================
#  BHSig-Hindi -- 70:15:15 Split
# ============================================================
#    Train users: 112 | Val users: 24 | Test users: 24
#    Creating train dataset...
#    Dataset: 6048 samples (2688 genuine + 3360 forged) from 112 users
#    Creating val dataset...
#    Dataset: 1296 samples (576 genuine + 720 forged) from 24 users
#    Creating test dataset...
#    Dataset: 1296 samples (576 genuine + 720 forged) from 24 users
#  > [System] Seed set to: 42
#    Using ImageNet initialization with CBAM
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 01/100 | Loss: 0.6138 | Acc: 69.70% | Val EER: 32.81% | Val Acc: 67.28%
#    >>> Saved! (EER: 32.81%)
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 02/100 | Loss: 0.4999 | Acc: 77.26% | Val EER: 19.97% | Val Acc: 80.02%
#    >>> Saved! (EER: 19.97%)
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 03/100 | Loss: 0.4542 | Acc: 79.29% | Val EER: 18.23% | Val Acc: 81.87%
#    >>> Saved! (EER: 18.23%)
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 04/100 | Loss: 0.4111 | Acc: 81.97% | Val EER: 18.06% | Val Acc: 81.87%
#    >>> Saved! (EER: 18.06%)
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 05/100 | Loss: 0.4106 | Acc: 81.84% | Val EER: 20.83% | Val Acc: 79.17%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 06/100 | Loss: 0.3828 | Acc: 83.52% | Val EER: 17.88% | Val Acc: 82.02%
#    >>> Saved! (EER: 17.88%)
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 07/100 | Loss: 0.3864 | Acc: 83.07% | Val EER: 23.09% | Val Acc: 76.93%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 08/100 | Loss: 0.3985 | Acc: 83.07% | Val EER: 18.58% | Val Acc: 81.33%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 09/100 | Loss: 0.3454 | Acc: 84.89% | Val EER: 15.62% | Val Acc: 84.34%
#    >>> Saved! (EER: 15.62%)
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 10/100 | Loss: 0.3297 | Acc: 86.15% | Val EER: 18.40% | Val Acc: 81.64%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 11/100 | Loss: 0.3492 | Acc: 84.93% | Val EER: 17.19% | Val Acc: 82.87%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 12/100 | Loss: 0.3174 | Acc: 86.37% | Val EER: 18.06% | Val Acc: 81.94%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 13/100 | Loss: 0.2871 | Acc: 87.94% | Val EER: 18.06% | Val Acc: 81.87%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 14/100 | Loss: 0.3259 | Acc: 86.58% | Val EER: 19.97% | Val Acc: 79.94%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 15/100 | Loss: 0.3515 | Acc: 85.95% | Val EER: 18.40% | Val Acc: 81.56%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 16/100 | Loss: 0.3286 | Acc: 86.78% | Val EER: 18.92% | Val Acc: 81.02%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 17/100 | Loss: 0.3210 | Acc: 85.85% | Val EER: 17.36% | Val Acc: 82.64%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 18/100 | Loss: 0.2580 | Acc: 89.34% | Val EER: 16.84% | Val Acc: 83.10%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 19/100 | Loss: 0.2346 | Acc: 90.36% | Val EER: 15.97% | Val Acc: 84.10%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 20/100 | Loss: 0.2471 | Acc: 90.53% | Val EER: 17.71% | Val Acc: 82.33%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 21/100 | Loss: 0.2473 | Acc: 89.68% | Val EER: 15.80% | Val Acc: 84.26%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 22/100 | Loss: 0.2078 | Acc: 91.53% | Val EER: 16.32% | Val Acc: 83.64%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 23/100 | Loss: 0.1866 | Acc: 92.34% | Val EER: 15.80% | Val Acc: 84.10%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 24/100 | Loss: 0.1808 | Acc: 92.99% | Val EER: 16.67% | Val Acc: 83.33%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 25/100 | Loss: 0.1736 | Acc: 92.94% | Val EER: 17.71% | Val Acc: 82.25%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 26/100 | Loss: 0.1670 | Acc: 93.22% | Val EER: 17.53% | Val Acc: 82.48%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 27/100 | Loss: 0.1632 | Acc: 93.60% | Val EER: 18.40% | Val Acc: 81.56%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 28/100 | Loss: 0.1699 | Acc: 93.27% | Val EER: 17.19% | Val Acc: 82.95%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 29/100 | Loss: 0.1467 | Acc: 94.38% | Val EER: 17.53% | Val Acc: 82.41%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 30/100 | Loss: 0.1443 | Acc: 94.34% | Val EER: 17.19% | Val Acc: 82.79%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 31/100 | Loss: 0.1486 | Acc: 94.13% | Val EER: 18.06% | Val Acc: 82.02%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 32/100 | Loss: 0.1392 | Acc: 94.20% | Val EER: 16.32% | Val Acc: 83.56%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 33/100 | Loss: 0.1310 | Acc: 94.96% | Val EER: 17.19% | Val Acc: 82.79%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 34/100 | Loss: 0.1285 | Acc: 94.91% | Val EER: 16.32% | Val Acc: 83.64%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 35/100 | Loss: 0.1251 | Acc: 95.37% | Val EER: 16.84% | Val Acc: 83.18%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 36/100 | Loss: 0.1250 | Acc: 94.88% | Val EER: 17.36% | Val Acc: 82.64%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 37/100 | Loss: 0.1104 | Acc: 95.75% | Val EER: 17.36% | Val Acc: 82.64%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 38/100 | Loss: 0.1108 | Acc: 95.47% | Val EER: 17.01% | Val Acc: 82.95%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 39/100 | Loss: 0.1053 | Acc: 95.94% | Val EER: 17.19% | Val Acc: 82.79%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 40/100 | Loss: 0.1027 | Acc: 96.37% | Val EER: 17.36% | Val Acc: 82.79%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 41/100 | Loss: 0.1023 | Acc: 95.84% | Val EER: 17.88% | Val Acc: 81.94%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 42/100 | Loss: 0.0990 | Acc: 96.22% | Val EER: 17.36% | Val Acc: 82.56%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 43/100 | Loss: 0.1061 | Acc: 96.19% | Val EER: 16.49% | Val Acc: 83.33%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 44/100 | Loss: 0.1086 | Acc: 95.69% | Val EER: 17.36% | Val Acc: 82.72%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 45/100 | Loss: 0.1080 | Acc: 95.77% | Val EER: 17.19% | Val Acc: 82.79%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 46/100 | Loss: 0.1002 | Acc: 95.90% | Val EER: 16.49% | Val Acc: 83.41%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 47/100 | Loss: 0.1016 | Acc: 95.97% | Val EER: 16.84% | Val Acc: 83.18%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 48/100 | Loss: 0.1002 | Acc: 96.17% | Val EER: 17.36% | Val Acc: 82.64%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 49/100 | Loss: 0.1053 | Acc: 95.80% | Val EER: 17.19% | Val Acc: 82.95%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 50/100 | Loss: 0.0974 | Acc: 96.17% | Val EER: 16.84% | Val Acc: 83.02%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 51/100 | Loss: 0.0932 | Acc: 96.33% | Val EER: 16.49% | Val Acc: 83.41%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 52/100 | Loss: 0.0981 | Acc: 96.00% | Val EER: 16.67% | Val Acc: 83.41%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 53/100 | Loss: 0.0937 | Acc: 96.20% | Val EER: 16.49% | Val Acc: 83.56%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 54/100 | Loss: 0.1093 | Acc: 95.79% | Val EER: 16.84% | Val Acc: 83.18%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 55/100 | Loss: 0.0866 | Acc: 96.50% | Val EER: 16.32% | Val Acc: 83.56%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 56/100 | Loss: 0.0925 | Acc: 96.52% | Val EER: 16.84% | Val Acc: 83.10%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 57/100 | Loss: 0.0992 | Acc: 96.15% | Val EER: 17.01% | Val Acc: 82.95%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 58/100 | Loss: 0.1011 | Acc: 96.32% | Val EER: 16.67% | Val Acc: 83.26%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 59/100 | Loss: 0.0975 | Acc: 96.38% | Val EER: 16.67% | Val Acc: 83.26%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 60/100 | Loss: 0.0909 | Acc: 96.57% | Val EER: 17.01% | Val Acc: 83.10%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 61/100 | Loss: 0.1031 | Acc: 96.05% | Val EER: 17.01% | Val Acc: 82.95%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 62/100 | Loss: 0.0976 | Acc: 96.25% | Val EER: 17.01% | Val Acc: 82.72%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 63/100 | Loss: 0.1012 | Acc: 95.99% | Val EER: 16.67% | Val Acc: 83.26%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 64/100 | Loss: 0.0905 | Acc: 96.45% | Val EER: 16.67% | Val Acc: 83.49%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 65/100 | Loss: 0.0935 | Acc: 96.60% | Val EER: 16.49% | Val Acc: 83.49%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 66/100 | Loss: 0.1025 | Acc: 96.27% | Val EER: 16.49% | Val Acc: 83.41%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 67/100 | Loss: 0.0954 | Acc: 96.42% | Val EER: 16.32% | Val Acc: 83.64%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 68/100 | Loss: 0.1147 | Acc: 95.70% | Val EER: 16.67% | Val Acc: 83.33%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 69/100 | Loss: 0.0977 | Acc: 96.27% | Val EER: 16.49% | Val Acc: 83.41%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 70/100 | Loss: 0.0869 | Acc: 96.72% | Val EER: 16.49% | Val Acc: 83.49%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 71/100 | Loss: 0.0955 | Acc: 96.29% | Val EER: 16.84% | Val Acc: 83.26%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 72/100 | Loss: 0.0953 | Acc: 96.14% | Val EER: 16.49% | Val Acc: 83.49%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 73/100 | Loss: 0.0880 | Acc: 96.50% | Val EER: 16.49% | Val Acc: 83.41%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 74/100 | Loss: 0.0933 | Acc: 96.40% | Val EER: 16.84% | Val Acc: 83.18%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 75/100 | Loss: 0.0920 | Acc: 96.70% | Val EER: 16.49% | Val Acc: 83.56%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 76/100 | Loss: 0.0908 | Acc: 96.65% | Val EER: 17.01% | Val Acc: 83.10%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 77/100 | Loss: 0.1008 | Acc: 96.22% | Val EER: 16.32% | Val Acc: 83.64%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 78/100 | Loss: 0.0949 | Acc: 96.47% | Val EER: 16.84% | Val Acc: 83.10%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 79/100 | Loss: 0.0938 | Acc: 96.25% | Val EER: 16.84% | Val Acc: 83.18%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 80/100 | Loss: 0.0949 | Acc: 96.27% | Val EER: 16.67% | Val Acc: 83.64%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 81/100 | Loss: 0.0924 | Acc: 96.37% | Val EER: 16.84% | Val Acc: 83.26%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 82/100 | Loss: 0.0982 | Acc: 96.22% | Val EER: 16.32% | Val Acc: 83.64%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 83/100 | Loss: 0.0853 | Acc: 96.50% | Val EER: 16.32% | Val Acc: 83.64%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 84/100 | Loss: 0.0959 | Acc: 96.37% | Val EER: 16.49% | Val Acc: 83.49%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 85/100 | Loss: 0.0975 | Acc: 96.29% | Val EER: 16.49% | Val Acc: 83.56%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 86/100 | Loss: 0.0903 | Acc: 96.42% | Val EER: 16.49% | Val Acc: 83.49%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 87/100 | Loss: 0.0905 | Acc: 96.73% | Val EER: 16.49% | Val Acc: 83.64%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 88/100 | Loss: 0.0939 | Acc: 96.43% | Val EER: 16.67% | Val Acc: 83.33%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 89/100 | Loss: 0.0973 | Acc: 96.32% | Val EER: 16.32% | Val Acc: 83.56%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 90/100 | Loss: 0.0967 | Acc: 96.38% | Val EER: 16.49% | Val Acc: 83.49%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 91/100 | Loss: 0.1010 | Acc: 95.89% | Val EER: 17.01% | Val Acc: 83.02%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 92/100 | Loss: 0.0982 | Acc: 96.19% | Val EER: 16.84% | Val Acc: 83.26%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 93/100 | Loss: 0.0903 | Acc: 96.45% | Val EER: 16.49% | Val Acc: 83.49%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 94/100 | Loss: 0.0936 | Acc: 96.42% | Val EER: 16.67% | Val Acc: 83.33%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 95/100 | Loss: 0.0975 | Acc: 96.38% | Val EER: 16.67% | Val Acc: 83.41%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 96/100 | Loss: 0.0944 | Acc: 96.24% | Val EER: 16.49% | Val Acc: 83.49%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 97/100 | Loss: 0.0925 | Acc: 96.19% | Val EER: 17.01% | Val Acc: 83.02%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 98/100 | Loss: 0.0970 | Acc: 96.17% | Val EER: 16.67% | Val Acc: 83.41%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 99/100 | Loss: 0.0906 | Acc: 96.45% | Val EER: 17.01% | Val Acc: 83.02%
# Training:   0%|          | 0/201 [00:00<?, ?it/s]
#    Epoch 100/100 | Loss: 0.0922 | Acc: 96.70% | Val EER: 16.49% | Val Acc: 83.49%
# Evaluating:   0%|          | 0/44 [00:00<?, ?it/s]
# ========== FINAL TEST RESULTS ==========
# EER            : 17.19%
# AUC            : 0.8908
# Best Threshold : 0.3166
# Accuracy       : 82.79%
# Precision      : 85.76%
# Recall         : 82.78%
# F1-Score       : 84.24%
# ========================================
#  > Saved ROC Plot to: ../model_evals/CBAM_hindi/CBAM_hindi_70-15-15/roc_curve.png
#  > Saved Distribution Plot to: ../model_evals/CBAM_hindi/CBAM_hindi_70-15-15/score_distribution.png
#  > Saved Confusion Matrix to: ../model_evals/CBAM_hindi/CBAM_hindi_70-15-15/confusion_matrix.png
#  > Saved DET Curve to: ../model_evals/CBAM_hindi/CBAM_hindi_70-15-15/det_curve.png
#  > Saved FAR/FRR Plot to: ../model_evals/CBAM_hindi/CBAM_hindi_70-15-15/far_frr.png
#
#    TEST SET RESULT: EER=17.19% | Acc=82.79% | AUC=0.8908 | F1=0.8424
#
# ============================================================
#  BHSig-Hindi -- 60:20:20 Split
# ============================================================
#    Train users: 96 | Val users: 32 | Test users: 32
#    Creating train dataset...
#    Dataset: 5184 samples (2304 genuine + 2880 forged) from 96 users
#    Creating val dataset...
#    Dataset: 1728 samples (768 genuine + 960 forged) from 32 users
#    Creating test dataset...
#    Dataset: 1728 samples (768 genuine + 960 forged) from 32 users
#  > [System] Seed set to: 42
#    Using ImageNet initialization with CBAM
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 01/100 | Loss: 0.6201 | Acc: 69.50% | Val EER: 32.29% | Val Acc: 67.71%
#    >>> Saved! (EER: 32.29%)
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 02/100 | Loss: 0.5294 | Acc: 74.55% | Val EER: 25.26% | Val Acc: 74.71%
#    >>> Saved! (EER: 25.26%)
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 03/100 | Loss: 0.4607 | Acc: 79.17% | Val EER: 23.57% | Val Acc: 76.45%
#    >>> Saved! (EER: 23.57%)
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 04/100 | Loss: 0.4451 | Acc: 80.62% | Val EER: 16.02% | Val Acc: 83.97%
#    >>> Saved! (EER: 16.02%)
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 05/100 | Loss: 0.4214 | Acc: 81.63% | Val EER: 19.27% | Val Acc: 80.73%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 06/100 | Loss: 0.4140 | Acc: 81.82% | Val EER: 19.01% | Val Acc: 81.02%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 07/100 | Loss: 0.3904 | Acc: 82.93% | Val EER: 17.32% | Val Acc: 82.81%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 08/100 | Loss: 0.3663 | Acc: 84.36% | Val EER: 17.45% | Val Acc: 82.64%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 09/100 | Loss: 0.3438 | Acc: 85.23% | Val EER: 19.92% | Val Acc: 80.03%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 10/100 | Loss: 0.3483 | Acc: 85.12% | Val EER: 18.62% | Val Acc: 81.42%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 11/100 | Loss: 0.3106 | Acc: 87.27% | Val EER: 18.23% | Val Acc: 81.77%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 12/100 | Loss: 0.3043 | Acc: 87.29% | Val EER: 17.97% | Val Acc: 82.06%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 13/100 | Loss: 0.2777 | Acc: 88.59% | Val EER: 17.58% | Val Acc: 82.41%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 14/100 | Loss: 0.2911 | Acc: 88.39% | Val EER: 17.19% | Val Acc: 82.75%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 15/100 | Loss: 0.2692 | Acc: 89.13% | Val EER: 16.80% | Val Acc: 83.22%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 16/100 | Loss: 0.2434 | Acc: 90.17% | Val EER: 15.89% | Val Acc: 84.38%
#    >>> Saved! (EER: 15.89%)
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 17/100 | Loss: 0.2368 | Acc: 90.47% | Val EER: 15.62% | Val Acc: 84.38%
#    >>> Saved! (EER: 15.62%)
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 18/100 | Loss: 0.2092 | Acc: 91.53% | Val EER: 15.36% | Val Acc: 84.61%
#    >>> Saved! (EER: 15.36%)
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 19/100 | Loss: 0.2131 | Acc: 91.26% | Val EER: 18.23% | Val Acc: 81.83%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 20/100 | Loss: 0.2050 | Acc: 91.53% | Val EER: 16.15% | Val Acc: 83.97%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 21/100 | Loss: 0.1984 | Acc: 92.02% | Val EER: 16.80% | Val Acc: 83.16%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 22/100 | Loss: 0.2104 | Acc: 91.40% | Val EER: 16.93% | Val Acc: 83.10%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 23/100 | Loss: 0.1873 | Acc: 92.67% | Val EER: 18.62% | Val Acc: 81.31%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 24/100 | Loss: 0.1942 | Acc: 92.40% | Val EER: 16.67% | Val Acc: 83.33%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 25/100 | Loss: 0.1747 | Acc: 92.67% | Val EER: 15.10% | Val Acc: 84.95%
#    >>> Saved! (EER: 15.10%)
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 26/100 | Loss: 0.1415 | Acc: 94.48% | Val EER: 14.71% | Val Acc: 85.19%
#    >>> Saved! (EER: 14.71%)
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 27/100 | Loss: 0.1431 | Acc: 94.57% | Val EER: 15.49% | Val Acc: 84.55%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 28/100 | Loss: 0.1454 | Acc: 94.22% | Val EER: 14.06% | Val Acc: 85.94%
#    >>> Saved! (EER: 14.06%)
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 29/100 | Loss: 0.1178 | Acc: 95.52% | Val EER: 14.45% | Val Acc: 85.65%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 30/100 | Loss: 0.1329 | Acc: 94.96% | Val EER: 14.32% | Val Acc: 85.71%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 31/100 | Loss: 0.1163 | Acc: 95.41% | Val EER: 15.10% | Val Acc: 84.90%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 32/100 | Loss: 0.1289 | Acc: 95.39% | Val EER: 14.84% | Val Acc: 85.13%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 33/100 | Loss: 0.1198 | Acc: 95.45% | Val EER: 16.54% | Val Acc: 83.45%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 34/100 | Loss: 0.1065 | Acc: 95.91% | Val EER: 13.67% | Val Acc: 86.28%
#    >>> Saved! (EER: 13.67%)
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 35/100 | Loss: 0.1078 | Acc: 95.99% | Val EER: 14.71% | Val Acc: 85.36%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 36/100 | Loss: 0.1161 | Acc: 95.45% | Val EER: 15.10% | Val Acc: 84.95%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 37/100 | Loss: 0.1137 | Acc: 95.74% | Val EER: 15.89% | Val Acc: 84.09%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 38/100 | Loss: 0.1045 | Acc: 96.01% | Val EER: 15.23% | Val Acc: 84.72%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 39/100 | Loss: 0.1049 | Acc: 96.16% | Val EER: 15.36% | Val Acc: 84.66%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 40/100 | Loss: 0.1127 | Acc: 95.58% | Val EER: 16.15% | Val Acc: 83.85%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 41/100 | Loss: 0.0959 | Acc: 96.05% | Val EER: 15.49% | Val Acc: 84.49%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 42/100 | Loss: 0.0863 | Acc: 96.82% | Val EER: 15.36% | Val Acc: 84.55%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 43/100 | Loss: 0.0764 | Acc: 97.03% | Val EER: 15.76% | Val Acc: 84.26%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 44/100 | Loss: 0.0746 | Acc: 97.13% | Val EER: 15.49% | Val Acc: 84.49%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 45/100 | Loss: 0.0816 | Acc: 96.76% | Val EER: 13.67% | Val Acc: 86.40%
#    >>> Saved! (EER: 13.67%)
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 46/100 | Loss: 0.0772 | Acc: 97.33% | Val EER: 14.97% | Val Acc: 85.01%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 47/100 | Loss: 0.0614 | Acc: 97.62% | Val EER: 15.10% | Val Acc: 84.95%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 48/100 | Loss: 0.0757 | Acc: 97.13% | Val EER: 14.84% | Val Acc: 85.19%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 49/100 | Loss: 0.0689 | Acc: 97.64% | Val EER: 14.58% | Val Acc: 85.42%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 50/100 | Loss: 0.0638 | Acc: 97.56% | Val EER: 14.58% | Val Acc: 85.42%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 51/100 | Loss: 0.0674 | Acc: 97.42% | Val EER: 14.84% | Val Acc: 85.07%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 52/100 | Loss: 0.0565 | Acc: 97.64% | Val EER: 14.84% | Val Acc: 85.24%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 53/100 | Loss: 0.0634 | Acc: 97.75% | Val EER: 14.45% | Val Acc: 85.53%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 54/100 | Loss: 0.0562 | Acc: 97.79% | Val EER: 14.71% | Val Acc: 85.19%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 55/100 | Loss: 0.0496 | Acc: 98.16% | Val EER: 14.84% | Val Acc: 84.95%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 56/100 | Loss: 0.0541 | Acc: 97.95% | Val EER: 14.84% | Val Acc: 85.13%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 57/100 | Loss: 0.0588 | Acc: 97.87% | Val EER: 14.58% | Val Acc: 85.42%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 58/100 | Loss: 0.0539 | Acc: 97.98% | Val EER: 14.84% | Val Acc: 85.19%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 59/100 | Loss: 0.0511 | Acc: 98.22% | Val EER: 15.10% | Val Acc: 84.90%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 60/100 | Loss: 0.0483 | Acc: 98.29% | Val EER: 15.23% | Val Acc: 84.84%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 61/100 | Loss: 0.0541 | Acc: 98.04% | Val EER: 14.97% | Val Acc: 85.07%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 62/100 | Loss: 0.0503 | Acc: 98.31% | Val EER: 15.36% | Val Acc: 84.61%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 63/100 | Loss: 0.0501 | Acc: 98.06% | Val EER: 15.10% | Val Acc: 85.13%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 64/100 | Loss: 0.0459 | Acc: 98.18% | Val EER: 15.10% | Val Acc: 85.13%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 65/100 | Loss: 0.0521 | Acc: 98.16% | Val EER: 15.10% | Val Acc: 84.90%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 66/100 | Loss: 0.0459 | Acc: 98.37% | Val EER: 15.10% | Val Acc: 85.01%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 67/100 | Loss: 0.0538 | Acc: 98.22% | Val EER: 14.97% | Val Acc: 85.07%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 68/100 | Loss: 0.0447 | Acc: 98.59% | Val EER: 14.84% | Val Acc: 85.19%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 69/100 | Loss: 0.0498 | Acc: 98.16% | Val EER: 14.84% | Val Acc: 85.19%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 70/100 | Loss: 0.0447 | Acc: 98.49% | Val EER: 15.36% | Val Acc: 84.66%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 71/100 | Loss: 0.0470 | Acc: 98.57% | Val EER: 15.10% | Val Acc: 84.84%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 72/100 | Loss: 0.0461 | Acc: 98.47% | Val EER: 14.97% | Val Acc: 85.07%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 73/100 | Loss: 0.0505 | Acc: 98.00% | Val EER: 14.84% | Val Acc: 85.36%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 74/100 | Loss: 0.0447 | Acc: 98.37% | Val EER: 14.84% | Val Acc: 85.13%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 75/100 | Loss: 0.0454 | Acc: 98.33% | Val EER: 15.10% | Val Acc: 84.90%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 76/100 | Loss: 0.0459 | Acc: 98.47% | Val EER: 15.10% | Val Acc: 84.78%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 77/100 | Loss: 0.0451 | Acc: 98.26% | Val EER: 14.97% | Val Acc: 85.07%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 78/100 | Loss: 0.0428 | Acc: 98.35% | Val EER: 14.97% | Val Acc: 85.01%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 79/100 | Loss: 0.0487 | Acc: 98.43% | Val EER: 15.10% | Val Acc: 84.95%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 80/100 | Loss: 0.0466 | Acc: 98.28% | Val EER: 14.58% | Val Acc: 85.42%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 81/100 | Loss: 0.0492 | Acc: 98.20% | Val EER: 14.58% | Val Acc: 85.47%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 82/100 | Loss: 0.0496 | Acc: 98.16% | Val EER: 14.84% | Val Acc: 85.13%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 83/100 | Loss: 0.0476 | Acc: 98.22% | Val EER: 14.84% | Val Acc: 85.13%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 84/100 | Loss: 0.0526 | Acc: 98.18% | Val EER: 14.71% | Val Acc: 85.36%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 85/100 | Loss: 0.0510 | Acc: 98.20% | Val EER: 14.84% | Val Acc: 85.13%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 86/100 | Loss: 0.0445 | Acc: 98.51% | Val EER: 14.84% | Val Acc: 85.13%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 87/100 | Loss: 0.0426 | Acc: 98.53% | Val EER: 14.58% | Val Acc: 85.47%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 88/100 | Loss: 0.0522 | Acc: 98.06% | Val EER: 15.10% | Val Acc: 84.90%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 89/100 | Loss: 0.0504 | Acc: 98.16% | Val EER: 14.71% | Val Acc: 85.24%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 90/100 | Loss: 0.0526 | Acc: 98.28% | Val EER: 14.97% | Val Acc: 85.01%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 91/100 | Loss: 0.0501 | Acc: 98.06% | Val EER: 14.84% | Val Acc: 85.13%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 92/100 | Loss: 0.0451 | Acc: 98.26% | Val EER: 15.10% | Val Acc: 84.90%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 93/100 | Loss: 0.0488 | Acc: 98.33% | Val EER: 14.84% | Val Acc: 85.19%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 94/100 | Loss: 0.0431 | Acc: 98.37% | Val EER: 15.10% | Val Acc: 84.84%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 95/100 | Loss: 0.0533 | Acc: 98.16% | Val EER: 14.84% | Val Acc: 85.19%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 96/100 | Loss: 0.0529 | Acc: 97.93% | Val EER: 14.97% | Val Acc: 85.01%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 97/100 | Loss: 0.0470 | Acc: 98.29% | Val EER: 14.45% | Val Acc: 85.53%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 98/100 | Loss: 0.0435 | Acc: 98.45% | Val EER: 14.97% | Val Acc: 85.01%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 99/100 | Loss: 0.0459 | Acc: 98.45% | Val EER: 15.23% | Val Acc: 84.72%
# Training:   0%|          | 0/172 [00:00<?, ?it/s]
#    Epoch 100/100 | Loss: 0.0428 | Acc: 98.35% | Val EER: 14.45% | Val Acc: 85.59%
# Evaluating:   0%|          | 0/58 [00:00<?, ?it/s]
# ========== FINAL TEST RESULTS ==========
# EER            : 16.41%
# AUC            : 0.9021
# Best Threshold : 0.8617
# Accuracy       : 83.62%
# Precision      : 86.44%
# Recall         : 83.65%
# F1-Score       : 85.02%
# ========================================
#  > Saved ROC Plot to: ../model_evals/CBAM_hindi/CBAM_hindi_60-20-20/roc_curve.png
#  > Saved Distribution Plot to: ../model_evals/CBAM_hindi/CBAM_hindi_60-20-20/score_distribution.png
#  > Saved Confusion Matrix to: ../model_evals/CBAM_hindi/CBAM_hindi_60-20-20/confusion_matrix.png
#  > Saved DET Curve to: ../model_evals/CBAM_hindi/CBAM_hindi_60-20-20/det_curve.png
#  > Saved FAR/FRR Plot to: ../model_evals/CBAM_hindi/CBAM_hindi_60-20-20/far_frr.png
#
#    TEST SET RESULT: EER=16.41% | Acc=83.62% | AUC=0.9021 | F1=0.8502
#
# ============================================================
# ALL EXPERIMENTS COMPLETE
# ============================================================

# %% [markdown]
# # =============================================================================
# # STEP 7: SUMMARY TABLE
# # =============================================================================

# %%
# Print summary table
print(f"\n{'='*80}")
print(f"{'CBAM + DENSENET121 — ' + DATASET_NAME + ' SPLIT EVALUATION':^80}")
print(f"{'='*80}")
print(f"{'Split':<10} {'Train':<8} {'Val':<8} {'Test':<8} {'EER':<10} {'Accuracy':<10} {'AUC':<10} {'F1':<10}")
print(f"{'-'*80}")

for key, res in all_results.items():
    print(f"{res['split']:<10} {res['train_users']:<8} {res['val_users']:<8} {res['test_users']:<8} "
          f"{res['eer']:.4f}    {res['accuracy']:.4f}    {res['auc']:.4f}    {res['f1']:.4f}")

print(f"{'='*70}")

# Save results
results_path = os.path.join(CHECKPOINT_DIR, f'CBAM_{DATASET}_results.json')
with open(results_path, 'w') as f:
    json.dump(all_results, f, indent=2)
print(f"\n > Results saved to: {results_path}")
# Out:
# ================================================================================
#                CBAM + DENSENET121 — BHSig-Hindi SPLIT EVALUATION
# ================================================================================
# Split      Train    Val      Test     EER        Accuracy   AUC        F1
# --------------------------------------------------------------------------------
# 65:18:18   104      28       28       0.1711    0.8287    0.9161    0.8431
# 70:15:15   112      24       24       0.1719    0.8279    0.8908    0.8424
# 60:20:20   96       32       32       0.1641    0.8362    0.9021    0.8502
# ======================================================================
#
#  > Results saved to: ../checkpoints/CBAM_splits/CBAM_bhsig_hindi_results.json

# %% [markdown]
# # =============================================================================
# # STEP 8: VISUALIZATION
# # =============================================================================

# %%
# Bar chart: Metrics by split ratio
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle(f'CBAM +  DenseNet121 — {DATASET_NAME} Performance Across Splits', fontsize=16, fontweight='bold')

metrics_to_plot = ['eer', 'accuracy', 'f1']
titles = ['EER (Lower is Better)', 'Accuracy', 'F1-Score']
colors = ['steelblue', 'seagreen', 'coral']

for ax_idx, (metric, title) in enumerate(zip(metrics_to_plot, titles)):
    ax = axes[ax_idx]
    split_labels = []
    values = []
    
    for ratio in SPLIT_RATIOS:
        split_str = ratio.replace('_', ':')
        split_labels.append(split_str)
        key = f"{DATASET_NAME} ({split_str})"
        values.append(all_results.get(key, {}).get(metric, 0))
    
    bars = ax.bar(split_labels, values, color=colors, alpha=0.8, edgecolor='black')
    ax.set_xlabel('Split Ratio', fontsize=12)
    ax.set_ylabel(title, fontsize=12)
    ax.set_title(title, fontsize=13, fontweight='bold')
    ax.grid(alpha=0.3, axis='y')
    
    # Add value labels on bars
    for bar, val in zip(bars, values):
        ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 0.005,
                f'{val:.4f}', ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plot_path = os.path.join(CHECKPOINT_DIR, f'cbam_{DATASET}_comparison.png')
plt.savefig(plot_path, dpi=150, bbox_inches='tight')
plt.show()
print(f" > Plot saved to: {plot_path}")
# Out:
#  > Plot saved to: ../checkpoints/CBAM_splits/cbam_bhsig_hindi_comparison.png
